# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import math
import random
from pprint import pprint

# %%
os.chdir("C:\\Users\\Milos\\Desktop\\Jovana")

# %%
data= pd.read_csv('winequality-red.csv',sep =';',skiprows=1,names=['fixed_acidity','volatile_acidity','citrix_acid','residual_sugar','chlorides','free_sulfur_dioxide','total_sulfur_dioxide','density','pH','sulphates','alcohol','quality'],na_values='?')

# %%
data
# Out:
#       fixed_acidity  volatile_acidity  citrix_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.shape
# Out:
# (1599, 12)

# %%
data.isnull().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citrix_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.describe()
# Out:
#        fixed_acidity  volatile_acidity  citrix_acid  residual_sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# number of values for each quality
sns.catplot(x='quality', data = data, kind = 'count')

# %%
# volatile acidity vs Quality
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'volatile_acidity', data = data)
# citric acid vs Quality
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'citrix_acid', data = data)
# fixed acidity vs Quality
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'fixed_acidity', data = data)
# residual_sugar vs Quality
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'residual_sugar', data = data)
# chlorides vs Quality
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'chlorides', data = data)
# free sulfur dioxide vs Quality
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'free_sulfur_dioxide', data = data)
# total sulfur dioxide vs Quality
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'total_sulfur_dioxide', data = data)
# density vs Quality
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'density', data = data)
# pH vs Quality
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'pH', data = data)
# sulphates vs Quality
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'sulphates', data = data)
# alcohol vs Quality
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'alcohol', data = data)

# %%
corr = data.corr()
plt.figure(figsize=(15,8))
a = sns.heatmap(corr, annot=True, fmt='.2f', cmap='magma')

# %% [markdown]
# # Prediction using sklearn

# %%
from sklearn.model_selection import train_test_split
# now split dataset into training data and test data: 75% / 25%
#train, test = train_test_split(data, test_size=0.2)
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
x = data.drop('quality', axis=1)
y = data['quality'].apply(lambda y_value:1 if y_value>=7 else 0)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.25,random_state=2)

# %%
print(y.shape, y_train.shape, y_test.shape)
# Out:
# (1599,) (1199,) (400,)

# %%
model = RandomForestClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
x_test_prediction = model.predict(x_test)
test_data_accuracy = accuracy_score(x_test_prediction, y_test)

# %%
test_data_accuracy
# Out:
# 0.9175

# %%
input_data = (7,0.27,0.36,20.7,0.045,45,170,1.001,3,0.45,8.8)
input_data_reshape = np.asarray(input_data).reshape(1,-1)

# %%
prediction = model.predict(input_data_reshape)
prediction
#prediction is an array of length 1 
if prediction[0]==1:
    print('Good quality wine')
else:
    print('Bad quality wine')
# Out:
# Bad quality wine

# %%
for i, row in data.iterrows():
    prediction_all = model.predict([[data.fixed_acidity[i],data.volatile_acidity[i],data.citrix_acid[i],data.residual_sugar[i],data.chlorides[i],data.free_sulfur_dioxide[i],data.total_sulfur_dioxide[i],data.density[i],data.pH[i],data.sulphates[i],data.alcohol[i],]])
    print(prediction_all)
    if prediction_all[0]==1:
        print('Good quality wine')
    else:
        print('Bad quality wine')
# Out:
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [1]
# Good quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [1]
# Good quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# Bad quality wine
# [0]
# ...

# %%
from sklearn.model_selection import train_test_split

# Columns used as predictors
X = data.drop(["quality"], axis = 1).values

y = data["quality"].values

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 2, test_size = 0.25)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier()
model.fit(X_train, y_train)

print(model.score(X_test, y_test))
# Out:
# 0.55

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)

print(model.score(X_test, y_test))
# Out:
# 0.59

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)

print(model.score(X_test, y_test))
# Out:
# 0.3124928694445772

# %%
from sklearn.neural_network import MLPClassifier
classifier = MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(10, 3), random_state=2)

model = MLPClassifier()
model.fit(X_train, y_train)

print(model.score(X_test, y_test))
# Out:
# 0.5875
# C:\Users\Milos\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# # Random forest algorithm

# %% [markdown]
# Functions

# %%
def create_leaf(data):

    label_column = data[:, -1]
    leaf = np.mean(label_column)
    
    return leaf

# %%
def get_potential_splits(data):
    
    potential_splits = {}
    n_rows, n_columns = data.shape
    for column_index in range(n_columns - 1):
        values = data[:, column_index]
        unique_values = np.unique(values)
        
        potential_splits[column_index] = unique_values
    
    return potential_splits

# %%
def split_data(data, split_column, split_value):
    
    split_column_values = data[:, split_column]
    data_below = data[split_column_values <= split_value]
    data_above = data[split_column_values >  split_value]    
    return data_below, data_above

# %%
def calculate_mse(data):
    actual_values = data[:, -1]
    # empty data => object => error
    if len(actual_values) == 0:   
        mse = 0
        
    else:
        prediction = np.mean(actual_values)
        mse = np.mean((actual_values - prediction) **2)
    
    return mse

# %%
def calculate_overall_metric(data_below, data_above, metric_function):
    
    n = len(data_below) + len(data_above)
    p_data_below = len(data_below) / n
    p_data_above = len(data_above) / n

    overall_metric =  (p_data_below * metric_function(data_below) 
                     + p_data_above * metric_function(data_above))
    
    return overall_metric

# %%
def determine_best_split(data, potential_splits):
    
    first_iteration = True
    for column_index in potential_splits:
        for value in potential_splits[column_index]:
            data_below, data_above = split_data(data, split_column=column_index, split_value=value)
            
            current_overall_metric = calculate_overall_metric(data_below, data_above, metric_function=calculate_mse)

            if first_iteration or current_overall_metric <= best_overall_metric:
                first_iteration = False
                
                best_overall_metric = current_overall_metric
                best_split_column = column_index
                best_split_value = value
    
    return best_split_column, best_split_value

# %%
len(data)
# Out:
# 1599

# %% [markdown]
# # Decision tree

# %%
def decision_tree_algorithm(df, counter=0, min_samples_split=2, max_depth=11):
    
    # data preparations
    if counter == 0:
        global COLUMN_HEADERS, FEATURE_TYPES
        COLUMN_HEADERS = df.columns
        FEATURE_TYPES = determine_type_of_feature(df)
        data = df.values
    else:
        data = df           
    
    
    # base cases
    if  (len(data) < min_samples_split) or (counter == max_depth):
        leaf = create_leaf(data)
        return leaf

    
    # recursive part
    else:    
        counter += 1

        potential_splits = get_potential_splits(data)
        split_column, split_value = determine_best_split(data, potential_splits)
        data_below, data_above = split_data(data, split_column, split_value)
        
        # check for empty data
        if len(data_below) == 0 or len(data_above) == 0:
            leaf = create_leaf(data)
            return leaf
        
        # determine question
        feature_name = COLUMN_HEADERS[split_column]
        type_of_feature = FEATURE_TYPES[split_column]
        if type_of_feature == "continuous":
            question = "{} <= {}".format(feature_name, split_value)
            
        # feature is categorical
        # in general
        else:
            question = "{} = {}".format(feature_name, split_value)
        
        # instantiate sub-tree
        sub_tree = {question: []}
        
        # find answers (recursion)
        yes_answer = decision_tree_algorithm(data_below, counter, min_samples_split, max_depth)
        no_answer = decision_tree_algorithm(data_above, counter, min_samples_split, max_depth)
        
        # If the answers are the same, then there is no point in asking the question.
        # This could happen when the data is classified even though it is not pure
        # yet (min_samples_split or max_depth base case).
        if yes_answer == no_answer:
            sub_tree = yes_answer
        else:
            sub_tree[question].append(yes_answer)
            sub_tree[question].append(no_answer)
        
        return sub_tree

# %%
def predict_example(example, tree):
    question = list(tree.keys())[0]
    feature_name, comparison_operator, value = question.split(" ")

    # ask question
    if comparison_operator == "<=":
        if example[feature_name] <= float(value):
            answer = tree[question][0]
        else:
            answer = tree[question][1]
    
    # feature is categorical
    else:
        if str(example[feature_name]) == value:
            answer = tree[question][0]
        else:
            answer = tree[question][1]

    # base case
    if not isinstance(answer, dict):
        return answer
    
    # recursive part
    else:
        residual_tree = answer
        return predict_example(example, residual_tree)


def decision_tree_predictions(test_df, tree):
    predictions = test_df.apply(predict_example, args=(tree,), axis=1)
    return predictions

# %% [markdown]
# # Forest

# %%
def train_test_split(df, test_size):

    if isinstance(test_size, float):
        test_size = round(test_size * len(df))

    indices = df.index.tolist()
    test_indices = random.sample(population=indices, k=test_size)

    test_df = df.loc[test_indices]
    train_df = df.drop(test_indices)

    return train_df, test_df

# %%
#train_test_split(data,0.25)

# %%
def bootstrapping(train_df, n_bootstrap):
    bootstrap_indices = np.random.randint(low=0, high=len(train_df), size=n_bootstrap) #Return random integers from the “discrete uniform” distribution of the specified dtype in the “half-open” interval [low, high).
    df_bootstrapped = train_df.iloc[bootstrap_indices]
    
    return df_bootstrapped

# %%
def determine_type_of_feature(df):
    
    feature_types = []
    n_unique_values_treshold = 15
    for feature in df.columns:
        if feature != "quality":
            unique_values = df[feature].unique()
            example_value = unique_values[0]

            if (isinstance(example_value, str)) or (len(unique_values) <= n_unique_values_treshold):
                feature_types.append("categorical")
            else:
                feature_types.append("continuous")
    
    return feature_types

# %%
def random_forest_algorithm(train_df, n_trees, n_bootstrap, n_features, dt_max_depth):
    forest = []
    for i in range(n_trees):
        df_bootstrapped = bootstrapping(train_df, n_bootstrap)
        tree = decision_tree_algorithm(df_bootstrapped, max_depth=dt_max_depth)#, random_subspace=n_features)
        forest.append(tree)
    
    return forest

# %%
def random_forest_predictions(test_df, forest):
    df_predictions = {}
    for i in range(len(forest)):
        column_name = "tree_{}".format(i)
        predictions = decision_tree_predictions(test_df, tree=forest[i])
        df_predictions[column_name] = predictions

    df_predictions = pd.DataFrame(df_predictions)
    random_forest_predictions = df_predictions.mean(axis=1) #[0]
    
    return random_forest_predictions

# %%
training_dataset=data[data['quality'].isna()==False]

# %%
forest_1=random_forest_algorithm(training_dataset,100,800,11,20)

# %%
forest_1
# Out:
# [{'alcohol <= 9.9': [{'sulphates <= 0.57': [{'sulphates <= 0.33': [4.0,
#        {'total_sulfur_dioxide <= 9.0': [6.0,
#          {'sulphates <= 0.5': [{'volatile_acidity <= 0.75': [{'alcohol <= 9.05': [{'pH <= 3.06': [5.0,
#                  4.0]},
#                {'pH <= 3.09': [6.0,
#                  {'pH <= 3.34': [{'chlorides <= 0.057': [{'alcohol <= 9.3': [4.0,
#                        5.0]},
#                      5.0]},
#                    {'chlorides <= 0.076': [{'sulphates <= 0.45': [5.0, 6.0]},
#                      {'sulphates <= 0.49': [5.0,
#                        {'pH <= 3.37': [6.0, 5.0]}]}]}]}]}]},
#              {'residual_sugar <= 2.2': [{'sulphates <= 0.48': [4.0, 5.0]},
#                5.0]}]},
#            {'chlorides <= 0.063': [6.0,
#              {'density <= 1.0001': [{'chlorides <= 0.066': [{'density <= 0.99655': [5.0,
#                    6.0]},
#                  {'alcohol <= 9.4': [{'volatile_acidity <= 0.67': [5.0,
# ...

# %%
new_values=random_forest_predictions(training_dataset,forest_1)

# %%
new=new_values

# %%
actual= data.quality
predicted = new

# %%
ss_res1=sum((actual-predicted)**2)
ss_tot1=sum((actual-actual.mean())**2)
accuracy_of_forest_1=1-ss_res1/ss_tot1
accuracy_of_forest_1
# Out:
# 0.8086752961912917

# %%
def plotplot(df, forest, title):    
    predictions = random_forest_predictions(df, forest)
    actual = df.quality
    plot_df = pd.DataFrame({"actual": actual, "predictions": predictions})
    
    plot_df.plot(figsize=(18, 5), title=title)
    
    return
plotplot(data,forest_1,'') #Graph that shows how accurate is out model

# %% [markdown]
# # Gini

# %%
df = pd.read_csv('winequality-red.csv',sep =';',skiprows=1,names=['fixed_acidity','volatile_acidity','citrix_acid','residual_sugar','chlorides','free_sulfur_dioxide','total_sulfur_dioxide','density','pH','sulphates','alcohol','quality_num'],na_values='?')

# %%
df['quality'] = df['quality_num'].apply(lambda y_value:1 if y_value>=7 else 0)
cdf = df.drop(columns='quality_num')
cdf
# Out:
#       fixed_acidity  volatile_acidity  citrix_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
def label_counts(data):
  
    labels = data.quality.unique()
    counts = {}
    
    for label in labels:
        counts[str(label)] = len(data[data['quality'] == label].index)

    return counts

# %%
cdf.quality.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
label_counts(cdf)
# Out:
# {'0': 1382, '1': 217}

# %%
def gini(data):
    counts = label_counts(data)
    impurity = 1.0
    for label in counts:
        probability = counts[label] / len(data.index)
        impurity -= probability**2

    return impurity

# %%
gini(data)
# Out:
# 0.6426632342524897

# %%
gini(cdf)
# Out:
# 0.234585327524512

# %%
def info_gain(data_below, data_above, gini_function):
    probability = len(data_below) / (len(data_below) + len(data_above))
    return gini_function - probability*gini(data_below) - (1 - probability)*gini(data_above)

# %%
def best_split(data, potential_splits):
    
    first_iteration = True
    for column_index in potential_splits:
        for value in potential_splits[column_index]:
            data_below, data_above = split_data(data, split_column=column_index, split_value=value)
            
            current_info_gain = info_gain(data_below, data_above, gini_function=gini)

            if first_iteration or current_info_gain <= best_info_gain:
                first_iteration = False
                
                best_info_gain = current_info_gain
                best_split_column = column_index
                best_split_value = value
    
    return best_split_column, best_split_value

# %%
def decision_tree_algorithm_gini(df, counter=0, min_samples_split=2, max_depth=11):
    
    # data preparations
    if counter == 0:
        global COLUMN_HEADERS, FEATURE_TYPES
        COLUMN_HEADERS = df.columns
        FEATURE_TYPES = determine_type_of_feature(df)
        data = df.values
    else:
        data = df           
    
    
    # base cases
    if  (len(data) < min_samples_split) or (counter == max_depth):
        leaf = create_leaf(data)
        return leaf

    
    # recursive part
    else:    
        counter += 1

        # helper functions 
        potential_splits = get_potential_splits(data)
        split_column, split_value = best_split(data, potential_splits)
        data_below, data_above = split_data(data, split_column, split_value)
        
        # check for empty data
        if len(data_below) == 0 or len(data_above) == 0:
            leaf = create_leaf(data)
            return leaf
        
        # determine question
        feature_name = COLUMN_HEADERS[split_column]
        type_of_feature = FEATURE_TYPES[split_column]
        if type_of_feature == "continuous":
            question = "{} <= {}".format(feature_name, split_value)
            
        # feature is categorical
        # ne treba nam ali generalno..
        else:
            question = "{} = {}".format(feature_name, split_value)
        
        # instantiate sub-tree
        sub_tree = {question: []}
        
        # find answers (recursion)
        yes_answer = decision_tree_algorithm_gini(data_below, counter, min_samples_split, max_depth)
        no_answer = decision_tree_algorithm_gini(data_above, counter, min_samples_split, max_depth)
        
        # If the answers are the same, then there is no point in asking the question.
        # This could happen when the data is classified even though it is not pure
        # yet (min_samples_split or max_depth base case).
        if yes_answer == no_answer:
            sub_tree = yes_answer
        else:
            sub_tree[question].append(yes_answer)
            sub_tree[question].append(no_answer)
        
        return sub_tree

# %%
def random_forest_algorithm_gini(train_df, n_trees, n_bootstrap, n_features, dt_max_depth):
    forest = []
    for i in range(n_trees):
        df_bootstrapped = bootstrapping(train_df, n_bootstrap)
        tree = decision_tree_algorithm_gini(df_bootstrapped, max_depth=dt_max_depth)#, random_subspace=n_features)
        forest.append(tree)
    
    return forest

# %% [markdown]
# # Binary quality column

# %%
training_cdf = cdf[cdf['quality'].isna()==False]

# %%
forest_2=random_forest_algorithm(training_cdf,100,800,11,20)

# %%
forest_2
# Out:
# [{'sulphates <= 0.67': [{'total_sulfur_dioxide <= 10.0': [{'alcohol <= 10.9': [0.0,
#        {'citrix_acid <= 0.46': [{'pH <= 3.4': [1.0, 0.0]}, 0.0]}]},
#      {'citrix_acid <= 0.31': [{'residual_sugar <= 1.9': [{'chlorides <= 0.084': [0.0,
#            {'volatile_acidity <= 0.58': [{'sulphates <= 0.54': [0.0, 1.0]},
#              0.0]}]},
#          0.0]},
#        {'alcohol <= 11.5': [{'citrix_acid <= 0.32': [{'sulphates <= 0.55': [0.0,
#              1.0]},
#            {'volatile_acidity <= 0.28': [{'alcohol <= 11.1': [{'pH <= 2.98': [1.0,
#                  0.0]},
#                1.0]},
#              {'citrix_acid <= 0.64': [0.0,
#                {'density <= 0.9994': [0.0, 1.0]}]}]}]},
#          {'pH <= 3.22': [{'pH <= 3.07': [0.0, 1.0]}, 0.0]}]}]}]},
#    {'alcohol <= 11.4': [{'total_sulfur_dioxide <= 49.0': [{'citrix_acid <= 0.63': [{'free_sulfur_dioxide <= 12.0': [{'volatile_acidity <= 0.31': [{'pH <= 3.21': [{'fixed_acidity <= 10.4': [0.0,
# ...

# %%
new_values = random_forest_predictions(training_cdf,forest_2)
new=new_values.round()
print(new_values)
actual = cdf.quality
predicted = new_values
# Out:
# 0       0.00
# 1       0.00
# 2       0.00
# 3       0.02
# 4       0.00
#         ...
# 1594    0.04
# 1595    0.09
# 1596    0.00
# 1597    0.08
# 1598    0.18
# Length: 1599, dtype: float64

# %%
ss_res2=sum((actual-predicted)**2)
ss_tot2=sum((actual-actual.mean())**2)
accuracy_of_forest_2=1-ss_res2/ss_tot2
accuracy_of_forest_2
# Out:
# 0.7759435733959257

# %%
def plotplot(df, forest, title):    
    predictions = random_forest_predictions(df, forest)
    actual = df.quality
    plot_df = pd.DataFrame({"actual": actual, "predictions": predictions})
    
    plot_df.plot(figsize=(18, 5), title=title)
    
    return
plotplot(cdf,forest_2,'') #Graph that shows how accurate is out model

# %%
#forest_2=random_forest_algorithm_gini(training_cdf,2,80,11,20)

# %%
#forest_2

# %% [markdown]
# def random_forest_predictions_gini(test_df, forest):
#     df_predictions = {}
#     for i in range(len(forest)):
#         column_name = "tree_{}".format(i)
#         predictions = decision_tree_predictions_gini(test_df, tree=forest[i])
#         df_predictions[column_name] = predictions
#
#     df_predictions = pd.DataFrame(df_predictions)
#     random_forest_predictions = df_predictions.mean(axis=1) #[0]
#
#     return random_forest_predictions_gini

# %%
#new_values=random_forest_predictions_gini(training_dataset,forest_1)
